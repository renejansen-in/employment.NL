# %% [markdown]
# # Employment.nl
# ## Mid bootcamp project | René Jansen
#
# This notebook is based the data set that is made available as open data by UWV WERKbedrijf for use by anyone who is interested. This data contains (anonymised) professional information from CVs and vacancies of Werk.nl.
# ### Documentation
# The data set is documentated <a href="data/doc/20210323_Specificatie_open_match_data_UWV_WERKbedrijf.pdf" target="_blank">here</a>.

# %%
# import base libraries 
import pandas as pd
import numpy as np

# set display options
pd.set_option('display.max_columns', None)          # view all columns in jupyter
pd.set_option('display.max_rows', 150)                 # view max rows in jupyter

# %%
# read UWV data
uwv = pd.DataFrame()
uwv_v = pd.DataFrame()
infile = 'data/UWVopenmatch 20211109/UWVopenmatchdata20211109.csv'

uwv  =  pd.read_csv(infile, 
                    sep=';',
                    parse_dates=['PEILDATUM']        # immediately accept as date
                    )

# %%
# base data set
print('Input EDA:', infile)
print('Number of rows:', uwv.shape[0])
print('Number of columns', uwv.shape[1])
uwv.head(3)
# headers look fine, uppercase is fine
# Out:
# Input EDA: data/UWVopenmatch 20211109/UWVopenmatchdata20211109.csv
# Number of rows: 172972
# Number of columns 39
#    PEILDATUM   BEROEP_CD      REFERENTIEBEROEP  BEROEPENCLUSTER_CD  \
# 0 2021-09-11  1000411471  Adviseur geotechniek        4.000000e+09
# 1 2021-09-11  1000411471  Adviseur geotechniek        4.000000e+09
# 2 2021-09-11  1000411471  Adviseur geotechniek        4.000000e+09
#
#                BEROEPENCLUSTER  POSTCODEGEBIED     PROVINCIE  \
# 0  Adviseurs weg- en waterbouw          2408.0  Zuid-Holland
# 1  Adviseurs weg- en waterbouw          2566.0  Zuid-Holland
# 2  Adviseurs weg- en waterbouw          2600.0  Zuid-Holland
#
#               GEMEENTE  REC_TYPE  AANTAL  GEM_LEEFTIJD  AANTAL_MAN  \
# 0  Alphen aan den Rijn  Vacature       1           NaN         NaN
# 1         s Gravenhage  Vacature       2           NaN         NaN
# 2                Delft  Vacature       1           NaN         NaN
#
#    AANTAL_VROUW OPLNIV_GEM ZOEKSTRAAL_GEM AANT_JR_ERV_GEM  AANT_LEEFT_TOT_27  \
# 0           NaN        NaN            NaN             NaN                NaN
# 1           NaN        NaN            NaN             NaN                NaN
# 2           NaN        NaN            NaN             NaN                NaN
#
#    AANT_LEEFT_28_39  AANT_LEEFT_40_49  AANT_LEEFT_50_PLUS  \
# 0               NaN               NaN                 NaN
# 1               NaN               NaN                 NaN
# 2               NaN               NaN                 NaN
#
#    AANT_LEEFT_ONBEKEND  AANT_UPW_0_8  AANT_UPW_9_16  AANT_UPW_17_24  \
# 0                  NaN           NaN            NaN             NaN
# 1                  NaN           NaN            NaN             NaN
# 2                  NaN           NaN            NaN             NaN
#
#    AANT_UPW_25_32  AANT_UPW_33_PLUS  AANT_UPW_ONBEKEND  AANT_OPLNIV_1  \
# 0             NaN               NaN                NaN            NaN
# 1             NaN               NaN                NaN            NaN
# 2             NaN               NaN                NaN            NaN
#
#    AANT_OPLNIV_2  AANT_OPLNIV_3  AANT_OPLNIV_4  AANT_OPLNIV_5  AANT_OPLNIV_6  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
#
#    AANT_OPLNIV_ONBEKEND  AANT_WE_0_1  AANT_WE_1_3  AANT_WE_3_6  AANT_WE_7  \
# 0                   NaN          NaN          NaN          NaN        NaN
# 1                   NaN          NaN          NaN          NaN        NaN
# 2                   NaN          NaN          NaN          NaN        NaN
#
#    AANT_WE_ONBEKEND
# 0               NaN
# 1               NaN
# 2               NaN

# %%
# uwv.dtypes

# %% [markdown]
# ### Structure information
#
# Three types of information are provided by profession and geographical area (<span style="color:red"> REC_TYPE</span>):
# 1. Information about **desired professions (W)**: Every job seeker in werk.nl has indicated 1 to 3 professions in which he or she is specifically interested. If there are several professions belonging to the same reference profession, they are counted as '1'.
# 2. Information about professions in which the job seeker has **gained experience (E)**: Every job seeker in werk.nl can submit his/her full CV.
# 3. **Vacancy information (V)**: There is no threshold for this and these are therefore only given per postcode area. Aggregations by municipal, provincial or national level can be created yourself.

# %%
# Seems to be a combined dataset, so before dealing with NaN's it's
# important to understand REC_TYPE very well
uwv['REC_TYPE'].value_counts()
# It's a combined data set with three record types, of which 
# at least one (V) has to be treated differently (e.g. NaN's)
# Out:
# Vacature           113276
# ErvaringsBeroep     40887
# WensBeroep          18809
# Name: REC_TYPE, dtype: int64

# %%
# For further exploration splitting uwv data, using numeric for efficiency
# uwv_v = Vacature                   113276 --> 0
# uwv_e = ErvaringsBeroep             40887 --> 1
# uwv_w = WensBeroep                  18809 --> 2
uwv["REC_TYPE"].replace({"Vacature": "0", "ErvaringsBeroep": "1", "WensBeroep": "2"}, inplace=True)
uwv["REC_TYPE"] = pd.to_numeric(uwv["REC_TYPE"])

# %% [markdown]
# ### Decision to split dataframe
# The Vacancies record type (0) appears to be filled in differently (NaN) than the other two record types for job seekers. NaN cleaning will therefore be two seperate processes, where ErvaringsBeroep and WensBeroep (1 and 2) will be treated equally.

# %%
mask = uwv['REC_TYPE'] == 0
uwv_v = uwv[mask]             # all vacancy info
uwv = uwv[~mask]          # all job seekers info
# Check records:         113276 + 59696 = 172972

# %% [markdown]
# ### Dealing with NaN and DQ - Vacancies

# %%
# All features in Vacancies (uwv_v) which contain NaN
for col in uwv_v.columns:            
    if uwv_v[col].isna().sum() != 0:
        print(col, uwv_v[col].isna().sum())                # comment in/out
print()       
print(uwv_v.shape)
# Out:
# BEROEPENCLUSTER_CD 1
# BEROEPENCLUSTER 1
# GEM_LEEFTIJD 113276
# AANTAL_MAN 113276
# AANTAL_VROUW 113276
# OPLNIV_GEM 113276
# ZOEKSTRAAL_GEM 113276
# AANT_JR_ERV_GEM 113276
# AANT_LEEFT_TOT_27 113276
# AANT_LEEFT_28_39 113276
# AANT_LEEFT_40_49 113276
# AANT_LEEFT_50_PLUS 113276
# AANT_LEEFT_ONBEKEND 113276
# AANT_UPW_0_8 113276
# AANT_UPW_9_16 113276
# AANT_UPW_17_24 113276
# AANT_UPW_25_32 113276
# AANT_UPW_33_PLUS 113276
# AANT_UPW_ONBEKEND 113276
# AANT_OPLNIV_1 113276
# AANT_OPLNIV_2 113276
# AANT_OPLNIV_3 113276
# AANT_OPLNIV_4 113276
# AANT_OPLNIV_5 113276
# AANT_OPLNIV_6 113276
# AANT_OPLNIV_ONBEKEND 113276
# AANT_WE_0_1 113276
# AANT_WE_1_3 113276
# AANT_WE_3_6 113276
# AANT_WE_7 113276
# AANT_WE_ONBEKEND 113276
#
# (113276, 39)

# %%
# Drop last 29 columns - not used by Vacancies
# df.iloc[row_start:row_end , col_start, col_end]
uwv_v = uwv_v.iloc[: , :-29]   # select everything, except for the last 29 columns

# %%
# One NaN left
# BEROEPENCLUSTER_CD 1
# BEROEPENCLUSTER 1
# both on record 13360 - decision to delete row
# rows_NaN = ['Position']
uwv_v = uwv_v.dropna()
# Use this during cleaning for dealing with NaN: shows insights for NaN on record level
# if ANY NaN is still present, repeat untill is empty
uwv_v[uwv_v.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [PEILDATUM, BEROEP_CD, REFERENTIEBEROEP, BEROEPENCLUSTER_CD, BEROEPENCLUSTER, POSTCODEGEBIED, PROVINCIE, GEMEENTE, REC_TYPE, AANTAL]
# Index: []

# %%
# Convert from float to int
uwv_v['BEROEPENCLUSTER_CD'] = uwv_v['BEROEPENCLUSTER_CD'].astype(int)
uwv_v['POSTCODEGEBIED'] = uwv_v['POSTCODEGEBIED'].astype(int)
uwv_v.dtypes
# Out:
# PEILDATUM             datetime64[ns]
# BEROEP_CD                      int64
# REFERENTIEBEROEP              object
# BEROEPENCLUSTER_CD             int64
# BEROEPENCLUSTER               object
# POSTCODEGEBIED                 int64
# PROVINCIE                     object
# GEMEENTE                      object
# REC_TYPE                       int64
# AANTAL                         int64
# dtype: object

# %%
uwv_v.head()
# Out:
#    PEILDATUM   BEROEP_CD      REFERENTIEBEROEP  BEROEPENCLUSTER_CD  \
# 0 2021-09-11  1000411471  Adviseur geotechniek          4000000026
# 1 2021-09-11  1000411471  Adviseur geotechniek          4000000026
# 2 2021-09-11  1000411471  Adviseur geotechniek          4000000026
# 3 2021-09-11  1000411471  Adviseur geotechniek          4000000026
# 4 2021-09-11  1000411471  Adviseur geotechniek          4000000026
#
#                BEROEPENCLUSTER  POSTCODEGEBIED     PROVINCIE  \
# 0  Adviseurs weg- en waterbouw            2408  Zuid-Holland
# 1  Adviseurs weg- en waterbouw            2566  Zuid-Holland
# 2  Adviseurs weg- en waterbouw            2600  Zuid-Holland
# 3  Adviseurs weg- en waterbouw            3013  Zuid-Holland
# 4  Adviseurs weg- en waterbouw            3511       Utrecht
#
#               GEMEENTE  REC_TYPE  AANTAL
# 0  Alphen aan den Rijn         0       1
# 1         s Gravenhage         0       2
# 2                Delft         0       1
# 3            Rotterdam         0       2
# 4              Utrecht         0       4

# %%
# uwv_v['REFERENTIEBEROEP'].value_counts()

# %% [markdown]
# ### Dealing with NaN and DQ - Job Seekers

# %%
# All features which contain NaN
for col in uwv.columns:            
    if uwv[col].isna().sum() != 0:
        print(col, uwv[col].isna().sum())                # comment in/out
print()       
print(uwv.shape)
# Out:
# BEROEPENCLUSTER_CD 10
# BEROEPENCLUSTER 10
# POSTCODEGEBIED 47950
# PROVINCIE 4121
# GEMEENTE 20519
# AANT_JR_ERV_GEM 18809
# AANT_UPW_0_8 18809
# AANT_UPW_9_16 18809
# AANT_UPW_17_24 18809
# AANT_UPW_25_32 18809
# AANT_UPW_33_PLUS 18809
# AANT_UPW_ONBEKEND 18809
# AANT_WE_0_1 18809
# AANT_WE_1_3 18809
# AANT_WE_3_6 18809
# AANT_WE_7 18809
# AANT_WE_ONBEKEND 18809
#
# (59696, 39)

# %%
# Series of columns with 18809 NaN
# In case of "wish/desired jobs": Columns UPW and WE are logically NaN, 
# for this data is all about experience: numbers of hours per week and 
# numbers of years experience.
# NaN decision: change to 0

def nan2zero(cols):
    for x in cols:
        uwv[x].fillna(0, inplace=True)

# Declaring the list
list_cols = [
            "AANT_JR_ERV_GEM","AANT_UPW_0_8","AANT_UPW_9_16","AANT_UPW_17_24","AANT_UPW_25_32","AANT_UPW_33_PLUS", 
            "AANT_UPW_ONBEKEND","AANT_WE_0_1","AANT_WE_1_3","AANT_WE_3_6","AANT_WE_7","AANT_WE_ONBEKEND"
            ]
# Calling the function
nan2zero(list_cols)

# %%
# BEROEPENCLUSTER_CD 10
# BEROEPENCLUSTER 10
# POSTCODEGEBIED 47950  (for privacy reasons UWV sets a threshold of 10 people per area)
# PROVINCIE 4121
# GEMEENTE 20519
#
# BEROEPENCLUSTER --> depreciated categories of jobs by UWV (probably old data) - DELETE 10 ROWS
rows_NaN = ['BEROEPENCLUSTER_CD']
uwv = uwv.dropna(subset = rows_NaN)
# Convert from float to int
uwv['BEROEPENCLUSTER_CD'] = uwv['BEROEPENCLUSTER_CD'].astype(int)

# %%
# Allowing postalcode to be 0, in order to use it later and not deleting
uwv['POSTCODEGEBIED'] = uwv['POSTCODEGEBIED'].fillna(0)
# Convert float to Int
uwv = uwv.astype({'POSTCODEGEBIED': 'int64',
                  'AANTAL_MAN': 'int64',
                  'AANTAL_VROUW': 'int64',
                  'AANT_LEEFT_TOT_27': 'int64', 
                  'AANT_LEEFT_28_39': 'int64', 
                  'AANT_LEEFT_40_49': 'int64', 
                  'AANT_LEEFT_50_PLUS': 'int64', 
                  'AANT_LEEFT_ONBEKEND': 'int64', 
                  'AANT_UPW_0_8': 'int64', 
                  'AANT_UPW_9_16': 'int64', 
                  'AANT_UPW_17_24': 'int64', 
                  'AANT_UPW_25_32': 'int64', 
                  'AANT_UPW_33_PLUS': 'int64', 
                  'AANT_UPW_ONBEKEND': 'int64', 
                  'AANT_OPLNIV_1': 'int64', 
                  'AANT_OPLNIV_2': 'int64', 
                  'AANT_OPLNIV_3': 'int64', 
                  'AANT_OPLNIV_4': 'int64', 
                  'AANT_OPLNIV_5': 'int64', 
                  'AANT_OPLNIV_6': 'int64', 
                  'AANT_OPLNIV_ONBEKEND': 'int64', 
                  'AANT_WE_0_1': 'int64', 
                  'AANT_WE_1_3': 'int64',                   
                  'AANT_WE_3_6': 'int64',                   
                  'AANT_WE_7': 'int64',                   
                  'AANT_WE_ONBEKEND': 'int64' })

# %%
# Convert strings to float
def make_float(x):
    if x==0:
        x='0'
    x = x.replace(",",".")
    return float(x)

cols = ['OPLNIV_GEM','ZOEKSTRAAL_GEM','AANT_JR_ERV_GEM']
for c in cols:
    uwv[c] = uwv[c].apply(make_float)
# uwv.dtypes

# %%
# Vacature           113276
# ErvaringsBeroep     40887
# WensBeroep          18809
# Name: REC_TYPE, dtype: int64

# PEILDATUM               datetime64[ns]
# BEROEP_CD                        int64
# REFERENTIEBEROEP                object
# BEROEPENCLUSTER_CD               int64
# BEROEPENCLUSTER                 object
# POSTCODEGEBIED                   int64
# PROVINCIE                       object
# GEMEENTE                        object
# REC_TYPE                         int64
# AANTAL                           int64 (vacancies) --> 113276

# AANTAL                           int64 (job seekers E + W) --> 59696
# GEM_LEEFTIJD                   float64
# AANTAL_MAN                       int64
# AANTAL_VROUW                     int64
# OPLNIV_GEM                     float64 
# ZOEKSTRAAL_GEM                 float64 
# AANT_JR_ERV_GEM                float64 

# AANT_LEEFT_TOT_27                int64 (E + W)
# AANT_LEEFT_28_39                 int64
# AANT_LEEFT_40_49                 int64
# AANT_LEEFT_50_PLUS               int64
# AANT_LEEFT_ONBEKEND              int64

# AANT_UPW_0_8                     int64 (E)
# AANT_UPW_9_16                    int64
# AANT_UPW_17_24                   int64
# AANT_UPW_25_32                   int64
# AANT_UPW_33_PLUS                 int64
# AANT_UPW_ONBEKEND                int64

# AANT_OPLNIV_1                    int64 (E + W)
# AANT_OPLNIV_2                    int64
# AANT_OPLNIV_3                    int64
# AANT_OPLNIV_4                    int64
# AANT_OPLNIV_5                    int64
# AANT_OPLNIV_6                    int64
# AANT_OPLNIV_ONBEKEND             int64

# AANT_WE_0_1                      int64 (E)
# AANT_WE_1_3                      int64
# AANT_WE_3_6                      int64
# AANT_WE_7                        int64
# AANT_WE_ONBEKEND                 int64

# %%
uwv.head()
# Out:
#     PEILDATUM   BEROEP_CD REFERENTIEBEROEP  BEROEPENCLUSTER_CD  \
# 19 2021-09-11  1000400819     Adviseur ict          4000000012
# 20 2021-09-11  1000400819     Adviseur ict          4000000012
# 21 2021-09-11  1000400819     Adviseur ict          4000000012
# 22 2021-09-11  1000400819     Adviseur ict          4000000012
# 23 2021-09-11  1000400819     Adviseur ict          4000000012
#
#              BEROEPENCLUSTER  POSTCODEGEBIED  PROVINCIE GEMEENTE  REC_TYPE  \
# 19  Adviseurs automatisering               0        NaN      NaN         1
# 20  Adviseurs automatisering               0        NaN      NaN         2
# 21  Adviseurs automatisering               0    Drenthe      NaN         1
# 22  Adviseurs automatisering               0    Drenthe      NaN         2
# 23  Adviseurs automatisering               0  Flevoland      NaN         1
#
#     AANTAL  GEM_LEEFTIJD  AANTAL_MAN  AANTAL_VROUW  OPLNIV_GEM  \
# 19    2427          52.0        1996           429        4.76
# 20    1011          50.0         862           149        4.66
# 21      47          56.0          42             5        4.66
# 22      19          55.0          17             2        4.63
# 23      70          52.0          62             8        4.61
#
#     ZOEKSTRAAL_GEM  AANT_JR_ERV_GEM  AANT_LEEFT_TOT_27  AANT_LEEFT_28_39  \
# 19           55.17             5.87                 26               314
# 20           55.81             0.00                 38               182
# 21           65.43             5.22                  0                 2
# 22           71.58             0.00                  0                 0
# 23           59.64             6.29                  0                 9
#
#     AANT_LEEFT_40_49  AANT_LEEFT_50_PLUS  AANT_LEEFT_ONBEKEND  AANT_UPW_0_8  \
# 19               515                1572                    0            42
# 20               222                 569                    0             0
# 21                 6                  39                    0             1
# 22                 3                  16                    0             0
# 23                12                  49                    0             2
#
#     AANT_UPW_9_16  AANT_UPW_17_24  AANT_UPW_25_32  AANT_UPW_33_PLUS  \
# 19             31              78             257              2006
# 20              0               0               0                 0
# 21              1               2               7                36
# 22              0               0               0                 0
# 23              1               1               6                59
#
#     AANT_UPW_ONBEKEND  AANT_OPLNIV_1  AANT_OPLNIV_2  AANT_OPLNIV_3  \
# 19                 13             24            108            314
# 20                  0             13             35            160
# 21                  0              0              5              2
# 22                  0              0              1              3
# 23                  1              0              4             10
#
#     AANT_OPLNIV_4  AANT_OPLNIV_5  AANT_OPLNIV_6  AANT_OPLNIV_ONBEKEND  \
# 19            275            956            750                     0
# 20            130            413            260                     0
# 21              6             25              9                     0
# 22              2              9              4                     0
# 23             11             29             16                     0
#
#     AANT_WE_0_1  AANT_WE_1_3  AANT_WE_3_6  AANT_WE_7  AANT_WE_ONBEKEND
# 19          437          705          609        663                13
# 20            0            0            0          0                 0
# 21           10           13           15          9                 0
# 22            0            0            0          0                 0
# 23           12           19           16         22                 1

# %%
print('SUMMARY LOCATION DATA')      
print('uwv_v - NaN:') 
for col in uwv_v.columns:            
    if uwv_v[col].isna().sum() != 0:
        print(col, uwv_v[col].isna().sum())                # comment in/out     
print(uwv_v.shape)
print('')  
print('uwv - NaN:') 
for col in uwv.columns:            
    if uwv[col].isna().sum() != 0:
        print(col, uwv[col].isna().sum())                # comment in/out      
print('')  
print('uwv - "put on 0":')
print('POSTCODEGEBIED 47940') 
print(uwv.shape)
# Out:
# SUMMARY LOCATION DATA
# uwv_v - NaN:
# (113275, 10)
#
# uwv - NaN:
# PROVINCIE 4111
# GEMEENTE 20509
#
# uwv - "put on 0":
# POSTCODEGEBIED 47940
# (59686, 39)

# %%
##### Prepare for joining in MySQL Workbench 
# FOUR aggregation levels possible on records at job seekers  
#
# PC    GEM    PROV 
# ------------------------------------------------------------
# 0     NaN    NaN    1. aggregated at national level
# 0     NaN    ".."   2. aggregated by province
# 0     ".."   ".."   3. aggregated by community/gemeente
# ".."  ".."   ".."   4. most detailed postal code level (P4)
#
# POSTCODEGEBIED                   int64
# PROVINCIE                       object
# GEMEENTE                        object
#
def nan2nl(cols):           # Replace NaN with generic NL
    for x in cols:
        uwv[x].fillna('NL', inplace=True)

# Declaring the list
list_cols = ['PROVINCIE', 'GEMEENTE']
# Calling the function
nan2nl(list_cols)

# %%
uwv.head(1)
# Out:
#     PEILDATUM   BEROEP_CD REFERENTIEBEROEP  BEROEPENCLUSTER_CD  \
# 19 2021-09-11  1000400819     Adviseur ict          4000000012
#
#              BEROEPENCLUSTER  POSTCODEGEBIED PROVINCIE GEMEENTE  REC_TYPE  \
# 19  Adviseurs automatisering               0        NL       NL         1
#
#     AANTAL  GEM_LEEFTIJD  AANTAL_MAN  AANTAL_VROUW  OPLNIV_GEM  \
# 19    2427          52.0        1996           429        4.76
#
#     ZOEKSTRAAL_GEM  AANT_JR_ERV_GEM  AANT_LEEFT_TOT_27  AANT_LEEFT_28_39  \
# 19           55.17             5.87                 26               314
#
#     AANT_LEEFT_40_49  AANT_LEEFT_50_PLUS  AANT_LEEFT_ONBEKEND  AANT_UPW_0_8  \
# 19               515                1572                    0            42
#
#     AANT_UPW_9_16  AANT_UPW_17_24  AANT_UPW_25_32  AANT_UPW_33_PLUS  \
# 19             31              78             257              2006
#
#     AANT_UPW_ONBEKEND  AANT_OPLNIV_1  AANT_OPLNIV_2  AANT_OPLNIV_3  \
# 19                 13             24            108            314
#
#     AANT_OPLNIV_4  AANT_OPLNIV_5  AANT_OPLNIV_6  AANT_OPLNIV_ONBEKEND  \
# 19            275            956            750                     0
#
#     AANT_WE_0_1  AANT_WE_1_3  AANT_WE_3_6  AANT_WE_7  AANT_WE_ONBEKEND
# 19          437          705          609        663                13

# %%
# uwv.loc[:, ['POSTCODEGEBIED','PROVINCIE','GEMEENTE']]
uwv['PC'] = np.where(uwv['POSTCODEGEBIED']!= 0, True, False)
uwv['GEM'] = np.where(uwv['GEMEENTE']!= 'NL', True, False)
uwv['PROV'] = np.where(uwv['PROVINCIE']!= 'NL', True, False)
uwv.head(100)
# Out:
#      PEILDATUM   BEROEP_CD                           REFERENTIEBEROEP  \
# 19  2021-09-11  1000400819                               Adviseur ict
# 20  2021-09-11  1000400819                               Adviseur ict
# 21  2021-09-11  1000400819                               Adviseur ict
# 22  2021-09-11  1000400819                               Adviseur ict
# 23  2021-09-11  1000400819                               Adviseur ict
# 24  2021-09-11  1000400819                               Adviseur ict
# 25  2021-09-11  1000400819                               Adviseur ict
# 26  2021-09-11  1000400819                               Adviseur ict
# 27  2021-09-11  1000400819                               Adviseur ict
# 28  2021-09-11  1000400819                               Adviseur ict
# 29  2021-09-11  1000400819                               Adviseur ict
# 30  2021-09-11  1000400819                               Adviseur ict
# 31  2021-09-11  1000400819                               Adviseur ict
# 32  2021-09-11  1000400819                               Adviseur ict
# 33  2021-09-11  1000400819                               Adviseur ict
# 34  2021-09-11  1000400819                               Adviseur ict
# 35  2021-09-11  1000400819                               Adviseur ict
# 36  2021-09-11  1000400819                               Adviseur ict
# 37  2021-09-11  1000400819                               Adviseur ict
# 38  2021-09-11  1000400819                               Adviseur ict
# 39  2021-09-11  1000400819                               Adviseur ict
# 40  2021-09-11  1000400819                               Adviseur ict
# 41  2021-09-11  1000400819                               Adviseur ict
# 42  2021-09-11  1000400819                               Adviseur ict
# 43  2021-09-11  1000400819                               Adviseur ict
# 44  2021-09-11  1000400819                               Adviseur ict
# 45  2021-09-11  1000400819                               Adviseur ict
# 46  2021-09-11  1000400819                               Adviseur ict
# 47  2021-09-11  1000400819                               Adviseur ict
# 48  2021-09-11  1000400819                               Adviseur ict
# 49  2021-09-11  1000400819                               Adviseur ict
# 50  2021-09-11  1000400819                               Adviseur ict
# 51  2021-09-11  1000400819                               Adviseur ict
# 52  2021-09-11  1000400819                               Adviseur ict
# 53  2021-09-11  1000400819                               Adviseur ict
# 54  2021-09-11  1000400819                               Adviseur ict
# 55  2021-09-11  1000400819                               Adviseur ict
# 56  2021-09-11  1000400819                               Adviseur ict
# 57  2021-09-11  1000400819                               Adviseur ict
# 58  2021-09-11  1000400819                               Adviseur ict
# 59  2021-09-11  1000400819                               Adviseur ict
# 60  2021-09-11  1000400819                               Adviseur ict
# 61  2021-09-11  1000400819                               Adviseur ict
# 62  2021-09-11  1000400819                               Adviseur ict
# 63  2021-09-11  1000400819                               Adviseur ict
# 64  2021-09-11  1000400819                               Adviseur ict
# 65  2021-09-11  1000400819                               Adviseur ict
# 66  2021-09-11  1000400819                               Adviseur ict
# 67  2021-09-11  1000400819                               Adviseur ict
# 68  2021-09-11  1000400819                               Adviseur ict
# 69  2021-09-11  1000400819                               Adviseur ict
# 70  2021-09-11  1000400819                               Adviseur ict
# 71  2021-09-11  1000400819                               Adviseur ict
# 72  2021-09-11  1000400819                               Adviseur ict
# 73  2021-09-11  1000400819                               Adviseur ict
# 74  2021-09-11  1000400819                               Adviseur ict
# 75  2021-09-11  1000400819                               Adviseur ict
# 76  2021-09-11  1000400819                               Adviseur ict
# 77  2021-09-11  1000400819                               Adviseur ict
# 78  2021-09-11  1000400819                               Adviseur ict
# 79  2021-09-11  1000400819                               Adviseur ict
# 80  2021-09-11  1000400819                               Adviseur ict
# 81  2021-09-11  1000400819                               Adviseur ict
# 82  2021-09-11  1000400819                               Adviseur ict
# 83  2021-09-11  1000400819                               Adviseur ict
# 84  2021-09-11  1000400819                               Adviseur ict
# 85  2021-09-11  1000400819                               Adviseur ict
# 86  2021-09-11  1000400819                               Adviseur ict
# 87  2021-09-11  1000400819                               Adviseur ict
# 88  2021-09-11  1000400819                               Adviseur ict
# 89  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 90  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 91  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 92  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 93  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 94  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 95  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 96  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 97  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 98  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 99  2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 100 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 101 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 102 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 103 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 104 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 105 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 106 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 107 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 114 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 116 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 122 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 123 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 124 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 127 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 128 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 129 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 130 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 131 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
# 132 2021-09-11  1000409622  Agrarisch seizoenskracht groente en fruit
#
#      BEROEPENCLUSTER_CD                BEROEPENCLUSTER  POSTCODEGEBIED  \
# 19           4000000012       Adviseurs automatisering               0
# 20           4000000012       Adviseurs automatisering               0
# 21           4000000012       Adviseurs automatisering               0
# 22           4000000012       Adviseurs automatisering               0
# 23           4000000012       Adviseurs automatisering               0
# 24           4000000012       Adviseurs automatisering               0
# 25           4000000012       Adviseurs automatisering               0
# 26           4000000012       Adviseurs automatisering               0
# 27           4000000012       Adviseurs automatisering               0
# 28           4000000012       Adviseurs automatisering               0
# 29           4000000012       Adviseurs automatisering               0
# 30           4000000012       Adviseurs automatisering               0
# 31           4000000012       Adviseurs automatisering               0
# 32           4000000012       Adviseurs automatisering               0
# 33           4000000012       Adviseurs automatisering               0
# 34           4000000012       Adviseurs automatisering               0
# 35           4000000012       Adviseurs automatisering               0
# 36           4000000012       Adviseurs automatisering               0
# 37           4000000012       Adviseurs automatisering               0
# 38           4000000012       Adviseurs automatisering               0
# 39           4000000012       Adviseurs automatisering               0
# 40           4000000012       Adviseurs automatisering               0
# 41           4000000012       Adviseurs automatisering               0
# 42           4000000012       Adviseurs automatisering               0
# 43           4000000012       Adviseurs automatisering               0
# 44           4000000012       Adviseurs automatisering               0
# 45           4000000012       Adviseurs automatisering               0
# 46           4000000012       Adviseurs automatisering               0
# 47           4000000012       Adviseurs automatisering               0
# 48           4000000012       Adviseurs automatisering               0
# 49           4000000012       Adviseurs automatisering               0
# 50           4000000012       Adviseurs automatisering               0
# 51           4000000012       Adviseurs automatisering               0
# 52           4000000012       Adviseurs automatisering               0
# 53           4000000012       Adviseurs automatisering               0
# 54           4000000012       Adviseurs automatisering               0
# 55           4000000012       Adviseurs automatisering               0
# 56           4000000012       Adviseurs automatisering               0
# 57           4000000012       Adviseurs automatisering               0
# 58           4000000012       Adviseurs automatisering               0
# 59           4000000012       Adviseurs automatisering               0
# 60           4000000012       Adviseurs automatisering               0
# 61           4000000012       Adviseurs automatisering               0
# 62           4000000012       Adviseurs automatisering               0
# 63           4000000012       Adviseurs automatisering               0
# 64           4000000012       Adviseurs automatisering               0
# 65           4000000012       Adviseurs automatisering               0
# 66           4000000012       Adviseurs automatisering               0
# 67           4000000012       Adviseurs automatisering               0
# 68           4000000012       Adviseurs automatisering               0
# 69           4000000012       Adviseurs automatisering               0
# 70           4000000012       Adviseurs automatisering               0
# 71           4000000012       Adviseurs automatisering               0
# 72           4000000012       Adviseurs automatisering               0
# 73           4000000012       Adviseurs automatisering               0
# 74           4000000012       Adviseurs automatisering               0
# 75           4000000012       Adviseurs automatisering               0
# 76           4000000012       Adviseurs automatisering               0
# 77           4000000012       Adviseurs automatisering               0
# 78           4000000012       Adviseurs automatisering               0
# 79           4000000012       Adviseurs automatisering               0
# 80           4000000012       Adviseurs automatisering               0
# 81           4000000012       Adviseurs automatisering               0
# 82           4000000012       Adviseurs automatisering               0
# 83           4000000012       Adviseurs automatisering               0
# 84           4000000012       Adviseurs automatisering               0
# 85           4000000012       Adviseurs automatisering               0
# 86           4000000012       Adviseurs automatisering               0
# 87           4000000012       Adviseurs automatisering               0
# 88           4000000012       Adviseurs automatisering               0
# 89           4000000363  Medewerkers land- en tuinbouw               0
# 90           4000000363  Medewerkers land- en tuinbouw               0
# 91           4000000363  Medewerkers land- en tuinbouw               0
# 92           4000000363  Medewerkers land- en tuinbouw               0
# 93           4000000363  Medewerkers land- en tuinbouw               0
# 94           4000000363  Medewerkers land- en tuinbouw               0
# 95           4000000363  Medewerkers land- en tuinbouw               0
# 96           4000000363  Medewerkers land- en tuinbouw               0
# 97           4000000363  Medewerkers land- en tuinbouw               0
# 98           4000000363  Medewerkers land- en tuinbouw               0
# 99           4000000363  Medewerkers land- en tuinbouw               0
# 100          4000000363  Medewerkers land- en tuinbouw               0
# 101          4000000363  Medewerkers land- en tuinbouw               0
# 102          4000000363  Medewerkers land- en tuinbouw               0
# 103          4000000363  Medewerkers land- en tuinbouw               0
# 104          4000000363  Medewerkers land- en tuinbouw               0
# 105          4000000363  Medewerkers land- en tuinbouw               0
# 106          4000000363  Medewerkers land- en tuinbouw               0
# 107          4000000363  Medewerkers land- en tuinbouw               0
# 114          4000000363  Medewerkers land- en tuinbouw            2573
#      AANT_LEEFT_50_PLUS  AANT_LEEFT_ONBEKEND  AANT_UPW_0_8  AANT_UPW_9_16  \
# 19                 1572                    0            42             31
# 20                  569                    0             0              0
# 21                   39                    0             1              1
# 22                   16                    0             0              0
# 23                   49                    0             2              1
# 24                   16                    0             0              0
# 25                   53                    0             3              1
# 26                   15                    0             0              0
# 27                  174                    0             6              4
# 28                   63                    0             0              0
# 29                   36                    0             1              4
# 30                   12                    0             0              0
# 31                  125                    0             4              0
# 32                   40                    0             0              0
# 33                  217                    0             4              3
# 34                   75                    0             0              0
# 35                  279                    0             3              4
# 36                  108                    0             0              0
# 37                   78                    0             3              2
# 38                   24                    0             0              0
# 39                  191                    0             2              4
# 40                   68                    0             0              0
# 41                   13                    0             3              0
# 42                    6                    0             0              0
# 43                  318                    0            10              7
# 44                  126                    0             0              0
# 45                    7                    0             1              0
# 46                   33                    0             2              1
# 47                   13                    0             0              0
# 48                   16                    0             1              2
# 49                    9                    0             0              0
# 50                   21                    0             0              0
# 51                    7                    0             0              0
# 52                   22                    0             0              0
# 53                   85                    0             2              1
# 54                   33                    0             0              0
# 55                   17                    0             0              0
# 56                    6                    0             0              0
# 57                   13                    0             1              0
# 58                    1                    0             0              0
# 59                   19                    0             1              0
# 60                    9                    0             0              0
# 61                    5                    0             0              0
# 62                    8                    0             0              1
# 63                    7                    0             0              0
# 64                    8                    0             0              1
# 65                   10                    0             0              0
# 66                   16                    0             1              1
# 67                    8                    0             0              1
# 68                    8                    0             0              0
# 69                    6                    0             0              0
# 70                    7                    0             1              0
# 71                   38                    0             0              0
# 72                   12                    0             0              0
# 73                   13                    0             1              0
# 74                    9                    0             0              0
# 75                    8                    0             0              0
# 76                   12                    0             0              0
# 77                   24                    0             1              2
# 78                    7                    0             0              0
# 79                   14                    0             0              0
# 80                    4                    0             0              0
# 81                   17                    0             0              0
# 82                   11                    0             1              0
# 83                    9                    0             0              0
# 84                    8                    0             0              0
# 85                   13                    0             0              1
# 86                    9                    0             0              0
# 87                    7                    0             0              0
# 88                    7                    0             0              0
# 89                    5                    0             0              0
# 90                   12                    0             3              1
# 91                   26                    0             4              4
# 92                    9                    0             0              0
# 93                    1                    0             1              0
# 94                    9                    0             4              2
# 95                    6                    0             0              0
# 96                    9                    0             0              0
# 97                    3                    0             2              1
# 98                   49                    0             5              6
# 99                    8                    0             0              0
# 100                  24                    0             1              1
# 101                   6                    0             1              0
# 102                  17                    0             2              6
# 103                   5                    0             0              0
# 104                  11                    0             2              1
# 105                   6                    0             0              1
# 106                  37                    0             3              1
# 107                  10                    0             0              0
# 114                   2                    0             0              0
# 116                   5                    0             0              0
# 122                   3                    0             0              0
# 123                  10                    0             0              0
# 124                   5                    0             0              1
# 127                   8                    0             1              2
# 128                   3                    0             0              0
# 129                   7                    0             0              0
# 130                   4                    0             0              1
# 131                   5                    0             0              2
# 132                  33                    0             0              4
#
#      AANT_UPW_17_24  AANT_UPW_25_32  AANT_UPW_33_PLUS  AANT_UPW_ONBEKEND  \
# 19               78             257              2006                 13
# 20                0               0                 0                  0
# 21                2               7                36                  0
# 100              3              1                     0           18
# 101              0              0                     0           10
# 102              6              1                     0           17
# 103              0              0                     0            7
# 104              1              1                     0            9
# 105              1              0                     0            4
# 106              8              0                     0           48
# 107              0              0                     0            0
# 114              0              0                     0            5
# 116              0              0                     0            6
# 122              2              0                     0            7
# 123              1              0                     0            8
# 124              0              0                     0            4
# 127              1              0                     0            4
# 128              0              0                     0            5
# 129              0              0                     0            7
# 130              0              1                     0            5
# 131              0              0                     0            7
# 132              2              0                     0           11
#
#      AANT_WE_1_3  AANT_WE_3_6  AANT_WE_7  AANT_WE_ONBEKEND     PC    GEM  \
# 19           705          609        663                13  False  False
# 20             0            0          0                 0  False  False
# 21            13           15          9                 0  False  False
# 22             0            0          0                 0  False  False
# 23            19           16         22                 1  False  False
# 24             0            0          0                 0  False  False
# 25            20           16         22                 0  False  False
# 26             0            0          0                 0  False  False
# 27            69           67         81                 1  False  False
# 28             0            0          0                 0  False  False
# 29            15           13         14                 0  False  False
# 30             0            0          0                 0  False  False
# 31            41           36         59                 2  False  False
# 32             0            0          0                 0  False  False
# 33            89           93         85                 3  False  False
# 34             0            0          0                 0  False  False
# 35           139          110        120                 2  False  False
# 36             0            0          0                 0  False  False
# 37            40           32         32                 0  False  False
# 38             0            0          0                 0  False  False
# 39           100           72         73                 1  False  False
# 40             0            0          0                 0  False  False
# 41             6            3          6                 1  False  False
# 42             0            0          0                 0  False  False
# 43           154          136        140                 2  False  False
# 44             0            0          0                 0  False  False
# 45             5            1          3                 0  False   True
# 46            10           14         17                 1  False   True
# 47             0            0          0                 0  False   True
# 48             5            5          5                 0  False   True
# 49             0            0          0                 0  False   True
# 50            11            6          6                 0  False   True
# 51             0            0          0                 0  False   True
# 52            10            7          9                 1  False   True
# 53            61           36         34                 0  False   True
# 54             0            0          0                 0  False   True
# 55             9            7          6                 0  False   True
# 56             0            0          0                 0  False   True
# 57             8            4          6                 0  False   True
# 58             0            0          0                 0  False   True
# 59            12            3          5                 1  False   True
# 60             0            0          0                 0  False   True
# 61             4            2          4                 0  False   True
# 62             4            2          4                 0  False   True
# 63             2            2          5                 0  False   True
# 64             2            1          6                 0  False   True
# 65             4            3          1                 0  False   True
# 66            10            7          5                 0  False   True
# 67             3            4          4                 0  False   True
# 68             4            5          2                 0  False   True
# 69             3            3          4                 1  False   True
# 70             3            1          7                 0  False   True
# 71            19           17         15                 0  False   True
# 72             0            0          0                 0  False   True
# 73             8            4          2                 0  False   True
# 74             2            3          3                 0  False   True
# 75             4            2          5                 0  False   True
# 76             5            2          6                 0  False   True
# 77            11           10          8                 0  False   True
# 78             0            0          0                 0  False   True
# 79             7            6          7                 0  False   True
# 80             0            0          0                 0  False   True
# 81             4            4          7                 0  False   True
# 82             2            4          4                 0  False   True
# 83             1            4          7                 0  False   True
# 84             3            0          6                 0  False   True
# 85             7            5          6                 0  False   True
# 86             8            6          2                 0  False   True
# 87             0            5          4                 0  False   True
# 88             0            0          0                 0  False   True
# 89             0            0          0                 0  False   True
# 90             5            2          3                 1  False   True
# 91            24            9          6                 5  False   True
# 92             0            0          0                 0  False   True
# 93             7            4          2                 0  False   True
# 94             5            5          2                 0  False   True
# 95             2            1          1                 0  False   True
# 96             7            3          0                 1  False   True
# 97             4            0          1                 0  False   True
# 98            25           14         11                 0  False   True
# 99             0            0          0                 0  False   True
# 100           14            9          2                 0  False   True
# 101            6            4          2                 0  False   True
# 102           15            9          5                 0  False   True
# 103            3            2          0                 0  False   True
# 104            5            4          6                 0  False   True
# 105            4            1          1                 0  False   True
# 106           35           22          6                 6  False   True
# 107            0            0          0                 0  False   True
# 114            6            1          0                 0   True   True
# 116            5            2          0                 0   True   True
# 122            3            1          1                 1   True   True
# 123            1            2          0                 0   True   True
# 124            2            2          1                 1   True   True
# 127            4            4          2                 0   True   True
# 128            3            2          0                 0   True   True
# 129            2            1          1                 0   True   True
# 130            2            2          1                 0   True   True
# 131            4            2          0                 0   True   True
# 132           10            8          9                 0   True   True
#
#       PROV
# 19   False
# 20   False
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# 57    True
# 58    True
# 59    True
# 60    True
# 61    True
# 62    True
# 63    True
# 64    True
# 65    True
# 66    True
# 67    True
# 68    True
# 69    True
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True
# 81    True
# 82    True
# 83    True
# 84    True
# 85    True
# 86    True
# 87    True
# 88    True
# 89    True
# 90    True
# 91    True
# 92    True
# 93    True
# 94    True
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# 100   True
# 101   True
# 102   True
# 103   True
# 104   True
# 105   True
# 106   True
# 107   True
# 114   True
# 116   True
# 122   True
# 123   True
# 124   True
# 127   True
# 128   True
# 129   True
# 130   True
# 131   True
# 132   True

# %% [markdown]
# ### Eliminate redundancy by joining - MySQL Workbench
#
# Since the original data set contains three types of records, cleaning is a proces of NaN's, improving columns and joining the data into meaningful records
#
# ![data_structure.jpg](attachment:data_structure.jpg)

# %%
import pymysql
from sqlalchemy import create_engine
import getpass  
password = getpass.getpass()

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/uwv_openmatch'
sqlEngine = create_engine(connection_string)

# query = '''select t.type, t.operation, t.amount as t_amount, t.balance, t.k_symbol, l.amount as l_amount, l.duration, l.payments, l.status
# from trans t
# left join loan l
# on t.account_id = l.account_id;'''
# data = pd.read_sql_query(query, engine)
# data.head()

tableName   = "jobseeker"
dataFrame   = pd.DataFrame(data=uwv)           # load uwv data

# sqlEngine       = create_engine('mysql+pymysql://root:@127.0.0.1/test', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:
    frame           = dataFrame.to_sql(tableName, dbConnection, if_exists='fail');
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()

# %%
tableName   = "vacancy"
dataFrame   = pd.DataFrame(data=uwv_v)           # load uwv data

# sqlEngine       = create_engine('mysql+pymysql://root:@127.0.0.1/test', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:
    frame           = dataFrame.to_sql(tableName, dbConnection, if_exists='fail');
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# Table 'vacancy' already exists.

# %%
# SMART SLICING / LOOK UPs for EDA
# dataframe.loc[specified rows: specified columns]
# uwv_v.loc[lambda df: uwv_v.BEROEP_CD == 1000409622, :]
# uwv_v.loc[lambda df: uwv_v.BEROEP_CD == 1000409622, :]

# %%
# # Slicing 
# uwv.loc[uwv['REC_TYPE'] == 0].head(60)
# # REC_TYPE = 0 (vacancies) show all NaN's on last columns --> not being used
# uwv.loc[uwv['REC_TYPE'] == 1].head(60)
# # REC_TYPE = 1 (experienced) show many NaN's on POSTCODEGEBIED and GEMEENTE
# uwv.loc[uwv['REC_TYPE'] == 2].head(60)

# %%
# OPLNIV
# 0 Niet bekend
# 1 Basisonderwijs
# 2 VMBO
# 3 Havo/VWO
# 4 MBO-algemeen
# 5 HBO/bachelor
# 6 WO/master
# Een gemiddeld opleidingsniveau van 4,32 duidt dus aan dat het tussen MBO en HBO ligt maar
# dichter bij MBO.

# %%
# Hoe is een postcode in Nederland opgebouwd?
# De eerste twee cijfers verwijzen naar de betreffende geografische regio
# De laatste twee cijfers duiden op een kleine woonplaats of wijk binnen een grote plaats
# De letters verwijzen naar een groep van ongeveer 25 woningen, bedrijfspanden of postbussen.

# %%
# Extension available
# beroepen.csv

# %%
# BO&C-register 
# Beroeps- en Opleidingsgegevens voor arbeidsmarkt professionals
# De Beroepen en Opleidingen database bevat een overzicht van de beroepen en opleidingen 
# die het UWV WERKbedrijf gebruikt bij het registreren van werkzoekenden en vacatures. Naast 
# actuele beroepen en opleidingen bevat de database historische beroeps- en opleidingsnamen, 
# korte schetsen en verschillende classificaties, zoals indelingen van beroepen en opleidingen 
# naar niveau, sector, BRC en ISCO. Al deze informatie wordt via deze downloadsite beschikbaar 
# gesteld voor professionele gebruikers.
#

# %%
# Werkzoekenden met een sollicitatieplicht
# kunnen via werk.nl hun verplichtingen vervullen. Er is geen speciale aandacht voor belastbaarheid
# van werknemers en de belasting van functies. Werkgevers kunnen vacatures plaatsen en in cv’s
# zoeken. De werkgever of werknemer moet zelf zoeken met een uitgebreide zoekfunctie. De matching vindt dus handmatig plaats. Werknemers moeten inloggen met hun DigiD om gebruik te
# kunnen maken van werk.nl. Er zijn geen kosten aan verbonden voor gebruik.

# %%
# For main question: it's about demand (V) and supply (W+E)
# in which regions come demand and supply least together --> scarcity

# %%
# "Aggregations by municipal, provincial or national level can be created yourself."
# perhaps additional tabels needed to do proper aggregation later
# 
# http://www.sqlblog.nl/postcodetabel-nederland-sql-script/

# %%
# # 6. Check NaN values per column.
# customer_df[customer_df.isna().any(axis=1)]   #or
# customer_df.isnull().sum()/len(customer_df)
